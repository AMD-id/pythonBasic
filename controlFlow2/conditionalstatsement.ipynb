# %% [markdown]
# 1. Introduction to conditional statements
# 2. if statement
# 3. else statement
# 4. elif statement
# 5. nested conditional statement
# 6. practical examples

# %%
## if statement

age=20
if age>=18:
    print("You are an adult.")
# Out:
# You are an adult.

# %%
## else statement
## the else block will execute if the condition in the if statement is false

age=16
if age>=18:
    print("You are an adult.")
else:
    print("You are a minor.")
# Out:
# You are a minor.

# %%
## elif statement
## elif allows you to check multiple conditions. You can have as many elif blocks as needed.

age=65
if age<18:
    print("You are a minor.")
elif age<65:
    print("You are an adult.")
else:
    print("You are a senior citizen.")
# Out:
# You are a senior citizen.

# %%
## nested conditional statements
age=20
if age>=18:
    print("Your age more than or equal to 18.")
    if age<65:
        print("You are an adult.")
    else:
        print("You are a senior citizen.")
else:
    print("You are a minor.")
# Out:
# Your age more than or equal to 18.
# You are an adult.

# %%
## another example of nested conditional statements

num=int(input("Enter a number: "))

if num>=0:
    print("The number is positive.")
    if num%2==0:
        print("The number is even.")
    else:
        print("The number is odd.")
else:
    print("The number is negative.")
# Out:
# The number is negative.

# %%
## determine if year is a leap year

year=int(input("Enter a year: "))

if year%4==0:
    if year%100==0:
        if year%400==0:
            print(year, "is a leap year.")
        else:
            print(year, "is not a leap year.")
    else:
        print(year, "is a leap year.")

else:
    print(year, "is not a leap year.")
